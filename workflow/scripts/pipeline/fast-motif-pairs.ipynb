# %%
# %load simulate_motif_pairs.py
import os
import itertools as it
import pandas as pd
from collections import defaultdict, Counter
import json
import numpy as np
import time
import argparse
import tempfile

# %%
###############################################################################
# Setup the commandline interface
###############################################################################
inputpath = '../../../results/fimo/Aortic-VIC.GSE154513.Homo_Sapiens.H3K27ac.b1/summarize_results/summary.txt'
#savepath = args.savepath
sims = 10
account_dist = "No"
within_dist = 2000000
blacklist_path = '../../../results/blacklists/hg38-blacklist.v2.bed'

# %%
# load the input data

df = pd.read_csv(inputpath, sep = '\t', header=0)
df.shape
# Out:
# (6816, 10)

# %%
import pybedtools as pbt
pbt.set_bedtools_path('<path-to-bedtools-bin>')

# %%
# loading pbt's of loops and blacklisted regions
loops_pbt = pbt.BedTool(inputpath)
blacklist_pbt = pbt.BedTool(blacklist_path)

# extract loops with no blacklist regions
loops_without_blk = loops_pbt.pair_to_bed(blacklist_pbt, type='neither')
loops_without_blk = loops_without_blk.to_dataframe(header=0, disable_auto_names=True)
columns = ['chr1', 'start1', 'end1',
           'chr2', 'start2', 'end2',
           'motif_ID_1', 'motif_name_1', 'motif_ID_2',
           'motif_name_2']
loops_without_blk.columns = columns

# make a temp dir
temp_dir = tempfile.TemporaryDirectory()
    
# Create a temporary file within the temporary directory
loops_without_blk_fn = os.path.basename(inputpath) + '.no_blacklist_regions'
loops_without_blk_fn = os.path.join(temp_dir.name, loops_without_blk_fn)
loops_without_blk.to_csv(loops_without_blk_fn, sep='\t', header=None, index=None)

# %%
loops_without_blk.shape
# Out:
# (6773, 10)

# %%
loops_without_blk
# Out:
#       chr1     start1       end1  chr2     start2       end2  \
# 0     chr1    1690000    1695000  chr1    1745000    1750000
# 1     chr1    2190000    2195000  chr1    2390000    2395000
# 2     chr1    2195000    2200000  chr1    2390000    2395000
# 3     chr1    3050000    3055000  chr1    3365000    3370000
# 4     chr1    8005000    8010000  chr1    8315000    8320000
# ...    ...        ...        ...   ...        ...        ...
# 6768  chrX  154020000  154025000  chrX  154040000  154045000
# 6769  chrX  154045000  154050000  chrX  154085000  154090000
# 6770  chrX  154375000  154380000  chrX  154395000  154400000
# 6771  chrX  154395000  154400000  chrX  154425000  154430000
# 6772  chrX  154725000  154730000  chrX  154745000  154750000
#
#                                              motif_ID_1  \
# 0     MA1961.1,MA1513.1,MA1945.1,MA1934.1,MA1941.1,M...
# 1     MA1972.1,MA1154.1,MA0039.4,MA1981.1,MA0599.1,M...
# 2     MA0114.4,MA0484.2,MA1976.1,MA0813.1,MA0815.1,M...
# 3                                                   NaN
# 4                            MA0149.1,MA1723.1,MA1596.1
# ...                                                 ...
# 6768                                           MA1576.1
# 6769                                  MA1596.1,MA1597.1
# 6770                                           MA1102.2
# 6771                                  MA1711.1,MA1723.1
# 6772                                           MA1124.1
#
#                                            motif_name_1  \
# 0     PATZ1,KLF15,ETV5::FIGLA,ERF::FIGLA,ETV2::FIGLA...
# 1     ZFP14,ZNF282,KLF4,ZNF530,KLF5,ETV5::FIGLA,EGR1...
# 2     HNF4A,HNF4G,ZNF320,TFAP2B,TFAP2C,TFAP2A,REL,CT...
# 3                                                   NaN
# 4                               EWSR1-FLI1,PRDM9,ZNF460
# ...                                                 ...
# 6768                                               THRB
# 6769                                      ZNF460,ZNF528
# 6770                                              CTCFL
# 6771                                       ZNF343,PRDM9
# 6772                                              ZNF24
#
#                                              motif_ID_2  \
# 0                                                   NaN
# 1     MA1589.1,MA0645.1,MA1122.1,MA1961.1,MA1513.1,M...
# 2     MA1589.1,MA0645.1,MA1122.1,MA1961.1,MA1513.1,M...
# 3                            MA1713.1,MA1977.1,MA1709.1
# 4     MA1653.1,MA1712.1,MA0609.2,MA0599.1,MA1513.1,M...
# ...                                                 ...
# 6768  MA1596.1,MA1149.1,MA1723.1,MA0597.2,MA1418.1,M...
# 6769                                           MA1596.1
# 6770                                  MA1711.1,MA1723.1
# 6771  MA1721.1,MA1522.1,MA1630.2,MA1653.1,MA1961.1,M...
# 6772                                                NaN
#
#                                            motif_name_2
# 0                                                   NaN
# 1     ZNF140,ETV6,TFDP1,PATZ1,KLF15,ZNF320,CDX2,TEAD...
# 2     ZNF140,ETV6,TFDP1,PATZ1,KLF15,ZNF320,CDX2,TEAD...
# 3                                    ZNF610,ZNF324,ZIM3
# 4     ZNF148,ZNF454,CREM,KLF5,KLF15,PATZ1,PRDM9,NEUROD1
# ...                                                 ...
# 6768  ZNF460,RARA::RXRG,PRDM9,THAP1,IRF3,ZNF140,ZNF1...
# 6769                                             ZNF460
# 6770                                       ZNF343,PRDM9
# 6771             ZNF93,MAZ,ZNF281,ZNF148,PATZ1,SP5,EBF3
# 6772                                                NaN
#
# [6773 rows x 10 columns]

# %%
# drop any anchors with no motifs in either anchor (contains NaN)
filter_df =  loops_without_blk.loc[(~loops_without_blk['motif_name_1'].isna()) & (~loops_without_blk['motif_name_2'].isna())].reset_index(drop=True)

# add the anchor names
def create_anchor_name(sr, anchor_no):
    anchor_name = '{}-{}-{}'.format(sr[f'chr{anchor_no}'], sr[f'start{anchor_no}'], sr[f'end{anchor_no}'])
    return(anchor_name)
filter_df.loc[:, 'anchor_name1'] = filter_df.apply(create_anchor_name, args=[1], axis=1)
filter_df.loc[:, 'anchor_name2'] = filter_df.apply(create_anchor_name, args=[2], axis=1)


###############################################################################
# Counting Observed Motif Pairs
###############################################################################
print('# Counting Observed')

def sort_motifs(motifs):
    sorted_motifs = tuple(sorted(motifs))
    return sorted_motifs

# Set up counter
motif_pair_counter = Counter()

# Loop through all enteries in dataframe
uniq_motif_pairs = []
for num in range(len(filter_df)):

    # Get motifs 1
    motifs1 = filter_df.motif_name_1[num].split(',')
    
    # JR-Fix: I tried to remove duplicates but removed self motifs in the process.
    # need to fix this.
    # Get motifs 2; to avoid duplicates motif pairs, motifs in anchor1 are removed
    # from motifs in anchor 2
    motifs2 = filter_df.motif_name_2[num].split(',')
    
    # Form the combination of all motif1 and motif2 pairs by
    # using the cross product
    combos = it.product(motifs1, motifs2)
    
    # Organize motifs into alphabetical order and drop duplicates
    combos = [sort_motifs(tmotifs) for tmotifs in combos]
    combos = sorted(set(combos))
    
    # Record them in counter
    for p in combos:
        motif_pair_counter[p] += 1
        uniq_motif_pairs.append(p)
        
uniq_motif_pairs = list(set(uniq_motif_pairs))

###############################################################################
# Construct Anchor Slots and Dictionary
###############################################################################
# An anchor slot is composed of a genetic region corresponding to a loop anchor
# and its constitutent motifs as a list. These are stored in dictionarys as:
# {'chr1-10000-15000': ['ACT', 'GGG', 'CGT']}. These anchor slots are used for
# simulation steps where the anchor slots are randomized.
print('# Construct Anchor Slots')

# Initialize the anchor slots data structure
anchor_slots = {}
anchor_shuffle_dict = {}
anchor_ids = []
motifs_count_sims = []

# Loop through all entries in dataframe
for i, sr in filter_df.iterrows():

    # Create anchor ids
    anchor1_id = sr['anchor_name1']
    anchor2_id = sr['anchor_name2']

    # Create blank list of anchors for shuffling based on distance
    entry_shuffle = []
    
    # Get chromosome
    chr1 = sr['chr1']
    chr2 = sr['chr2']

    # Put anchor ids and slots into list
    if anchor1_id not in anchor_slots:
        
        # Create the current slot
        motifs1 = list(sr.motif_name_1.split(','))
        anchor_slots[anchor1_id] = list(set(motifs1))
        anchor_ids.append(anchor1_id)

        # For the given slot, determine what anchors can be shuffled with it. If distance has been
        # provided then this will be applied.
        # Create column in dataframe to get distance measure for anchor 1
        # JR note: how is this calculating distance? Why are we using start1 of filter_df with start1 of sr?
        # JR note: I think I see how the distance is being calculated but you would have to check the end as well!
        filter_df['tmp_dist'] = abs(filter_df['start1'] - sr['start1'])
        if account_dist == 'Yes':

            # Only keep anchors within certain distance and within certain chromosome
            tmp_dist_df = filter_df[(filter_df['tmp_dist'] <= within_dist) & \
                                    (filter_df['chr1'] == chr1) & \
                                    (filter_df['chr2'] == chr2)].copy()

        else:
            # Only keep motifs within specific chromosome
            tmp_dist_df = filter_df[(filter_df['chr1'] == chr1) & \
                                    (filter_df['chr2'] == chr2)].copy()
        
        # Create anchor id for anchors within distance of anchor 1
        tmp_dist_df['anchor1_id_name'] = tmp_dist_df['chr1'] + '-' + \
                                            tmp_dist_df['start1'].astype('str') + '-' + \
                                            tmp_dist_df['end1'].astype('str')
        entry_shuffle += list(tmp_dist_df['anchor1_id_name'])

        # Create list of anchors wihin distance
        anchor_shuffle_dict[anchor1_id] = entry_shuffle

        # Get summary stats of amount of motifs in anchors
        motifs_count_sims.append(len(entry_shuffle))
    
    if anchor2_id not in anchor_slots:
        
        motifs2 = list(sr.motif_name_2.split(','))
        anchor_slots[anchor2_id] = list(set(motifs2))
        anchor_ids.append(anchor2_id)
        
        # Create column in dataframe to get distance measure for anchor 1
        filter_df['tmp_dist'] = abs(filter_df['start2'] - sr['start2'])
        if account_dist == 'Yes':

            # Only keep anchors within certain distance and within certain chromosome
            tmp_dist_df = filter_df[(filter_df['tmp_dist'] <= within_dist) & \
                                    (filter_df['chr1'] == chr1) & \
                                    (filter_df['chr2'] == chr2)].copy()

        else:
            # Only keep motifs within specific chromosome
            tmp_dist_df = filter_df[(filter_df['chr1'] == chr1) & \
                                    (filter_df['chr2'] == chr2)].copy()

        # Create anchor id for anchors within distance of anchor 2
        tmp_dist_df['anchor2_id_name'] = tmp_dist_df['chr2'] + '-' + \
                                            tmp_dist_df['start2'].astype('str') + '-' + \
                                            tmp_dist_df['end2'].astype('str')
        entry_shuffle += list(tmp_dist_df['anchor2_id_name'])

        # Create list of anchors within distance
        anchor_shuffle_dict[anchor2_id] = entry_shuffle

        # Get summary stats of amount of motifs in anchors
        motifs_count_sims.append(len(entry_shuffle))
# Out:
# # Counting Observed
# # Construct Anchor Slots

# %%
###############################################################################
# Conduct Simulations
###############################################################################
print('# Conduct Simulations')

sim_results = []
sim_idx = 0
num_loops = len(filter_df)

while sim_idx < sims:

    sims_motif_pair_counter = Counter()
    for anchor_name1, anchor_name2 in filter_df[['anchor_name1', 'anchor_name2']].values:

        # Simulate anchors based on chromsome and distance
        sim_anchors1 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True) 
        sim_anchors2 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True) 
        
        # Get motifs from simulated anchors
        # To remove duplicates motif pairs, motifs in anchor1 are removed from motifs in anchor 2
        sim_motifs1 = anchor_slots[sim_anchors1[0]]
        sim_motifs2 = anchor_slots[sim_anchors2[0]]
    
        # Form the combination of all motif1 and motif2 pairs by
        # using the cross product
        shuffle_combos = it.product(sim_motifs1, sim_motifs2)

        # Organize motifs into alphabetical order
        shuffle_combos = [sort_motifs(tmotifs) for tmotifs in shuffle_combos]
        shuffle_combos = sorted(set(shuffle_combos))

        # Record them in counter
        for p in shuffle_combos:
            sims_motif_pair_counter[p] += 1

    sim_results.append(sims_motif_pair_counter)
    sim_idx += 1
# Out:
# # Conduct Simulations
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 16
#      12 sims_motif_pair_counter = Counter()
#      13 for anchor_name1, anchor_name2 in filter_df[['anchor_name1', 'anchor_name2']].values:
#      14
#      15     # Simulate anchors based on chromsome and distance
# ---> 16     sim_anchors1 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True)
#      17     sim_anchors2 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True)
#      19     # Get motifs from simulated anchors
#      20     # To remove duplicates motif pairs, motifs in anchor1 are removed from motifs in anchor 2
#
# NameError: name 'anchor_name' is not defined

# %%
sims = 1000

# %%
###############################################################################
# Conduct Simulations
###############################################################################
print('# Conduct Simulations')

sim_results = [Counter() for sim in range(sims)]
sim_idx = 0
num_loops = len(filter_df)

sims_motif_pair_counter = Counter()
for anchor_name1, anchor_name2 in filter_df[['anchor_name1', 'anchor_name2']].values:

    # Simulate anchors based on chromsome and distance
    sim_anchors1 = np.random.choice(anchor_shuffle_dict[anchor_name], size=sims, replace=True) 
    sim_anchors2 = np.random.choice(anchor_shuffle_dict[anchor_name], size=sims, replace=True) 
    
    sim_idx = 0
    for (slot1, slot2) in zip(sim_anchors1, sim_anchors2):
    
        # Get motifs from simulated anchors
        # To remove duplicates motif pairs, motifs in anchor1 are removed from motifs in anchor 2
        sim_motifs1 = anchor_slots[slot1]
        sim_motifs2 = anchor_slots[slot2]

        # Form the combination of all motif1 and motif2 pairs by
        # using the cross product
        shuffle_combos = it.product(sim_motifs1, sim_motifs2)

        # Organize motifs into alphabetical order
        shuffle_combos = [sort_motifs(tmotifs) for tmotifs in shuffle_combos]
        shuffle_combos = sorted(set(shuffle_combos))

        # Record them in counter
        for p in shuffle_combos:
            sim_results[sim_idx][p] += 1 
        
        # Update counter
        sim_idx += 1
# Out:
# # Conduct Simulations

# %%
len(sim_results)
# Out:
# 1000

# %%
sim_results[0]
# Out:
# Counter({('ZNF460', 'ZNF93'): 253,
#          ('PRDM9', 'ZNF460'): 242,
#          ('PRDM9', 'ZNF93'): 232,
#          ('PRDM9', 'RARA::RXRG'): 186,
#          ('PATZ1', 'PRDM9'): 180,
#          ('PATZ1', 'ZNF460'): 167,
#          ('PATZ1', 'ZNF93'): 164,
#          ('RARA::RXRG', 'ZNF93'): 164,
#          ('PRDM9', 'SP5'): 164,
#          ('RARA::RXRG', 'ZNF460'): 153,
#          ('PRDM9', 'PRDM9'): 147,
#          ('SP5', 'ZNF460'): 146,
#          ('PRDM9', 'ZNF528'): 139,
#          ('ZNF528', 'ZNF93'): 138,
#          ('ZNF460', 'ZNF701'): 133,
#          ('PRDM9', 'RARA'): 133,
#          ('SP5', 'ZNF93'): 132,
#          ('PRDM9', 'ZNF454'): 125,
#          ('ZNF93', 'ZNF93'): 123,
#          ('PRDM9', 'RARA::RXRA'): 120,
#          ('MAZ', 'PRDM9'): 120,
#          ('PRDM9', 'ZNF148'): 120,
#          ('RARA', 'ZNF460'): 119,
#          ('EWSR1-FLI1', 'ZNF460'): 115,
#          ('MAZ', 'ZNF460'): 114,
#          ('ZNF148', 'ZNF460'): 114,
#          ('PATZ1', 'RARA::RXRG'): 112,
#          ('RARA::RXRA', 'ZNF460'): 111,
#          ('ZNF454', 'ZNF460'): 108,
#          ('MAZ', 'ZNF93'): 105,
#          ('ZNF148', 'ZNF93'): 105,
#          ('EWSR1-FLI1', 'PRDM9'): 105,
#          ('PRDM9', 'ZNF701'): 105,
#          ('RARA::RXRG', 'SP5'): 103,
#          ('ZNF454', 'ZNF93'): 103,
#          ('RARA', 'ZNF93'): 102,
#          ('PBX3', 'ZNF460'): 99,
#          ('RARA::RXRA', 'ZNF93'): 99,
#          ('EWSR1-FLI1', 'ZNF93'): 98,
#          ('ZNF343', 'ZNF460'): 96,
#          ('MYF5', 'PRDM9'): 95,
#          ('PRDM9', 'ZNF680'): 95,
#          ('PRDM9', 'ZNF768'): 95,
#          ('ZNF460', 'ZNF528'): 94,
#          ('MYF5', 'ZNF460'): 93,
#          ('ZNF460', 'ZNF680'): 93,
#          ('ZNF460', 'ZNF768'): 93,
#          ('KLF15', 'PRDM9'): 93,
#          ('ZNF701', 'ZNF93'): 92,
#          ('EBF3', 'ZNF93'): 92,
#          ('PRDM9', 'ZNF281'): 92,
#          ('PRDM9', 'ZBTB6'): 91,
#          ('PATZ1', 'ZNF528'): 91,
#          ('ZNF460', 'ZNF460'): 91,
#          ('RARA::RXRG', 'ZNF701'): 90,
#          ('ZBTB6', 'ZNF93'): 89,
#          ('PATZ1', 'SP5'): 89,
#          ('ZNF281', 'ZNF460'): 89,
#          ('EBF3', 'PRDM9'): 89,
#          ('ZKSCAN5', 'ZNF93'): 88,
#          ('THAP1', 'ZNF93'): 87,
#          ('KLF15', 'ZNF93'): 86,
#          ('FOXE1', 'ZNF93'): 86,
#          ('RARA::RXRG', 'ZNF528'): 85,
#          ('KLF4', 'ZNF93'): 85,
#          ('FOXE1', 'PRDM9'): 85,
#          ('KLF4', 'ZNF460'): 83,
#          ('PATZ1', 'ZNF454'): 82,
#          ('PATZ1', 'ZNF701'): 82,
#          ('PBX3', 'PRDM9'): 82,
#          ('ZNF343', 'ZNF93'): 82,
#          ('PRDM9', 'ZKSCAN5'): 81,
#          ('PRDM9', 'ZNF343'): 81,
#          ('ZNF281', 'ZNF93'): 80,
#          ('SP5', 'ZNF528'): 80,
#          ('MAZ', 'RARA::RXRG'): 79,
#          ('RARA::RXRG', 'ZNF148'): 79,
#          ('KLF4', 'PRDM9'): 79,
#          ('EWSR1-FLI1', 'PATZ1'): 78,
#          ('EWSR1-FLI1', 'RARA::RXRG'): 77,
#          ('SP5', 'ZNF701'): 77,
#          ('PATZ1', 'RARA::RXRA'): 75,
#          ('PRDM9', 'THAP1'): 74,
#          ('KLF15', 'ZNF460'): 74,
#          ('ZBTB6', 'ZNF460'): 74,
#          ('MYF5', 'ZNF93'): 73,
#          ('PATZ1', 'RARA'): 73,
#          ('ZNF680', 'ZNF93'): 73,
#          ('ZNF768', 'ZNF93'): 73,
#          ('PBX3', 'ZNF93'): 72,
#          ('RARA::RXRA', 'SP5'): 72,
#          ('PBX3', 'RARA::RXRG'): 71,
#          ('RARA::RXRA', 'RARA::RXRG'): 71,
#          ('EBF3', 'ZNF460'): 71,
#          ('PATZ1', 'PATZ1'): 70,
#          ('ZNF528', 'ZNF701'): 70,
#          ('ZKSCAN5', 'ZNF460'): 69,
#          ('RARA', 'SP5'): 69,
#          ('SP5', 'ZNF454'): 68,
#          ('RARA::RXRG', 'ZNF281'): 67,
#          ('PRDM9', 'RREB1'): 67,
#          ('PATZ1', 'ZKSCAN5'): 66,
#          ('MAZ', 'ZNF528'): 66,
#          ('ZNF148', 'ZNF528'): 66,
#          ('FOXE1', 'PATZ1'): 66,
#          ('ZNF320', 'ZNF460'): 65,
#          ('PRDM9', 'ZNF320'): 65,
#          ('PATZ1', 'ZNF343'): 65,
#          ('RARA::RXRG', 'ZNF454'): 65,
#          ('EWSR1-FLI1', 'SP5'): 64,
#          ('PATZ1', 'ZBTB6'): 64,
#          ('ZNF263', 'ZNF460'): 64,
#          ('ZNF460', 'ZNF610'): 64,
#          ('EBF3', 'PATZ1'): 64,
#          ('CTCFL', 'PRDM9'): 64,
#          ('FOXE1', 'ZNF460'): 63,
#          ('MAZ', 'PATZ1'): 63,
#          ('PATZ1', 'ZNF148'): 63,
#          ('KLF4', 'RARA::RXRG'): 63,
#          ('RREB1', 'ZNF460'): 63,
#          ('RARA::RXRG', 'RARA::RXRG'): 62,
#          ('THAP1', 'ZNF460'): 62,
#          ('IRF3', 'ZNF93'): 62,
#          ('ZNF135', 'ZNF93'): 62,
#          ('ZNF140', 'ZNF93'): 62,
#          ('PRDM9', 'ZNF263'): 61,
#          ('PRDM9', 'ZNF610'): 61,
#          ('EHF', 'ZNF460'): 61,
#          ('SP5', 'SP5'): 60,
#          ('EWSR1-FLI1', 'ZNF528'): 60,
#          ('EWSR1-FLI1', 'ZNF454'): 59,
#          ('RARA', 'ZNF701'): 59,
#          ('CTCFL', 'ZNF460'): 59,
#          ('PATZ1', 'PBX3'): 59,
#          ('SP5', 'ZNF343'): 59,
#          ('KLF15', 'SP5'): 58,
#          ('EBF3', 'RARA::RXRG'): 58,
#          ('RARA', 'RARA::RXRG'): 58,
#          ('EHF', 'ZNF93'): 57,
#          ('RARA::RXRA', 'ZNF528'): 57,
#          ('EWSR1-FLI1', 'RARA::RXRA'): 57,
#          ('RARA::RXRG', 'ZNF343'): 57,
#          ('MAZ', 'ZNF701'): 57,
#          ('ZNF148', 'ZNF701'): 57,
#          ('MAZ', 'ZNF454'): 57,
#          ('ZNF148', 'ZNF454'): 57,
#          ('PATZ1', 'THAP1'): 57,
#          ('RARA', 'ZNF528'): 56,
#          ('ZNF454', 'ZNF528'): 56,
#          ('KLF15', 'RARA::RXRG'): 56,
#          ('MAZ', 'RARA'): 56,
#          ('MYF5', 'PATZ1'): 56,
#          ('PATZ1', 'ZNF680'): 56,
#          ('PATZ1', 'ZNF768'): 56,
#          ('RARA', 'ZNF148'): 56,
#          ('RARA::RXRA', 'ZNF701'): 56,
#          ('ZNF263', 'ZNF93'): 56,
#          ('ZNF610', 'ZNF93'): 56,
#          ('CTCFL', 'ZNF93'): 56,
#          ('MAZ', 'SP5'): 56,
#          ('SP5', 'ZNF148'): 56,
#          ('FOXE1', 'SP5'): 56,
#          ('EWSR1-FLI1', 'RARA'): 55,
#          ('PBX3', 'SP5'): 55,
#          ('PATZ1', 'ZNF281'): 55,
#          ('EBF3', 'SP5'): 55,
#          ('EWSR1-FLI1', 'MAZ'): 54,
#          ('EWSR1-FLI1', 'ZNF148'): 54,
#          ('SP5', 'ZKSCAN5'): 54,
#          ('MAZ', 'RARA::RXRA'): 54,
#          ('MYF5', 'SP5'): 54,
#          ('RARA::RXRA', 'ZNF148'): 54,
#          ('SP5', 'ZNF680'): 54,
#          ('SP5', 'ZNF768'): 54,
#          ('FOXE1', 'RARA::RXRG'): 54,
#          ('ZNF281', 'ZNF528'): 54,
#          ('KLF4', 'PATZ1'): 53,
#          ('SP5', 'ZBTB6'): 53,
#          ('KLF15', 'PATZ1'): 53,
#          ('EHF', 'PRDM9'): 53,
#          ('RARA::RXRG', 'THAP1'): 53,
#          ('EBF3', 'ZNF528'): 53,
#          ('IRF3', 'PRDM9'): 53,
#          ('PRDM9', 'ZNF135'): 53,
#          ('PRDM9', 'ZNF140'): 53,
#          ('ZNF454', 'ZNF701'): 52,
#          ('ZNF343', 'ZNF528'): 52,
#          ('TFDP1', 'ZNF93'): 51,
#          ('KLF4', 'SP5'): 51,
#          ('RARA::RXRG', 'ZBTB6'): 51,
#          ('FOXE1', 'ZNF528'): 50,
#          ('RARA', 'ZNF281'): 50,
#          ('ZNF320', 'ZNF93'): 50,
#          ('RREB1', 'ZNF93'): 50,
#          ('SP5', 'THAP1'): 50,
#          ('MAZ', 'ZBTB6'): 49,
#          ('ZBTB6', 'ZNF148'): 49,
#          ('PBX3', 'ZNF528'): 49,
#          ('EBF3', 'ZNF454'): 49,
#          ('SP5', 'ZNF281'): 49,
#          ('RARA::RXRG', 'ZKSCAN5'): 48,
#          ('MYF5', 'ZNF528'): 48,
#          ('ZNF528', 'ZNF680'): 48,
#          ('ZNF528', 'ZNF768'): 48,
#          ('EBF3', 'ZNF701'): 48,
#          ('ZNF281', 'ZNF454'): 47,
#          ('MYF5', 'RARA::RXRG'): 47,
#          ('RARA::RXRG', 'ZNF680'): 47,
#          ('RARA::RXRG', 'ZNF768'): 47,
#          ('BNC2', 'ZNF460'): 47,
#          ('JUN', 'ZNF460'): 47,
#          ('MAZ', 'ZNF343'): 47,
#          ('ZNF148', 'ZNF343'): 47,
#          ('PRDM9', 'TFDP1'): 46,
#          ('THAP1', 'ZNF454'): 46,
#          ('KLF4', 'RARA'): 46,
#          ('RARA::RXRA', 'ZNF281'): 46,
#          ('TFDP1', 'ZNF460'): 46,
#          ('EBF3', 'RARA'): 46,
#          ('PATZ1', 'ZNF263'): 46,
#          ('PATZ1', 'ZNF610'): 46,
#          ('RARA::RXRG', 'ZNF320'): 45,
#          ('ZKSCAN5', 'ZNF454'): 45,
#          ('ZNF343', 'ZNF454'): 45,
#          ('FOXE1', 'ZNF454'): 45,
#          ('FOXE1', 'ZNF701'): 45,
#          ('FOXE1', 'RARA'): 45,
#          ('RARA', 'THAP1'): 45,
#          ('KLF4', 'ZNF454'): 44,
#          ('EWSR1-FLI1', 'ZBTB6'): 44,
#          ('MYF5', 'ZNF701'): 44,
#          ('ZNF680', 'ZNF701'): 44,
#          ('ZNF701', 'ZNF768'): 44,
#          ('PBX3', 'RARA'): 44,
#          ('PATZ1', 'ZNF320'): 44,
#          ('ZNF343', 'ZNF701'): 44,
#          ('RARA', 'RARA::RXRA'): 44,
#          ('ERF::NHLH1', 'PRDM9'): 44,
#          ('PRDM9', 'SOX2'): 44,
#          ('PRDM9', 'TEAD1'): 44,
#          ('PRDM9', 'ZNF257'): 44,
#          ('ZBTB6', 'ZNF701'): 43,
#          ('ZBTB6', 'ZNF454'): 43,
#          ('KLF15', 'ZNF528'): 43,
#          ('EWSR1-FLI1', 'MYF5'): 43,
#          ('EWSR1-FLI1', 'ZNF680'): 43,
#          ('EWSR1-FLI1', 'ZNF768'): 43,
#          ('KLF4', 'RARA::RXRA'): 43,
#          ('MAZ', 'MYF5'): 43,
#          ('MAZ', 'ZNF680'): 43,
#          ('MAZ', 'ZNF768'): 43,
#          ('MYF5', 'ZNF148'): 43,
#          ('ZNF148', 'ZNF680'): 43,
#          ('ZNF148', 'ZNF768'): 43,
#          ('MAZ', 'ZKSCAN5'): 43,
#          ('ZKSCAN5', 'ZNF148'): 43,
#          ('KLF15', 'ZNF701'): 43,
#          ('ZNF281', 'ZNF701'): 43,
#          ('PRDM9', 'ZNF675'): 43,
#          ('EBF3', 'RARA::RXRA'): 43,
#          ('RARA::RXRG', 'TFDP1'): 43,
#          ('THAP1', 'ZNF528'): 43,
#          ('CTCFL', 'RARA::RXRG'): 42,
#          ('EHF', 'RARA::RXRG'): 42,
#          ('KLF15', 'MAZ'): 42,
#          ('KLF15', 'ZNF148'): 42,
#          ('FOXE1', 'RARA::RXRA'): 42,
#          ('RARA::RXRA', 'THAP1'): 42,
#          ('FOXE1', 'MAZ'): 42,
#          ('FOXE1', 'ZNF148'): 42,
#          ('PBX3', 'RARA::RXRA'): 42,
#          ('KLF4', 'ZNF528'): 42,
#          ('THAP1', 'ZNF701'): 41,
#          ('ZBTB6', 'ZNF528'): 41,
#          ('MAZ', 'PBX3'): 41,
#          ('PBX3', 'ZNF148'): 41,
#          ('KLF15', 'ZNF454'): 41,
#          ('ZKSCAN5', 'ZNF701'): 41,
#          ('RARA::RXRG', 'RREB1'): 41,
#          ('RARA', 'ZNF343'): 40,
#          ('EWSR1-FLI1', 'ZNF281'): 40,
#          ('EWSR1-FLI1', 'ZNF701'): 40,
#          ('ZKSCAN5', 'ZNF528'): 40,
#          ('EBF3', 'MAZ'): 40,
#          ('EBF3', 'ZNF148'): 40,
#          ('KLF15', 'RARA'): 39,
#          ('EWSR1-FLI1', 'KLF15'): 39,
#          ('SP5', 'ZNF320'): 39,
#          ('EBF3', 'EWSR1-FLI1'): 39,
#          ('IRF3', 'PATZ1'): 39,
#          ('PATZ1', 'ZNF135'): 39,
#          ('PATZ1', 'ZNF140'): 39,
#          ('EHF', 'PATZ1'): 38,
#          ('KLF4', 'MAZ'): 38,
#          ('KLF4', 'ZNF148'): 38,
#          ('KLF4', 'ZBTB6'): 38,
#          ('KLF15', 'RARA::RXRA'): 38,
#          ('MYF5', 'ZNF281'): 38,
#          ('ZNF281', 'ZNF680'): 38,
#          ('ZNF281', 'ZNF768'): 38,
#          ('THRB', 'ZNF93'): 38,
#          ('PRDM9', 'STAT3'): 38,
#          ('RARA::RXRA', 'ZNF454'): 38,
#          ('KLF15', 'ZNF343'): 38,
#          ('NFE2L2', 'PRDM9'): 38,
#          ('EWSR1-FLI1', 'ZNF343'): 38,
#          ('EBF3', 'PBX3'): 38,
#          ('ZNF281', 'ZNF343'): 38,
#          ('ZBTB6', 'ZNF281'): 37,
#          ('PBX3', 'ZNF454'): 37,
#          ('PRDM1', 'PRDM9'): 37,
#          ('PRDM9', 'ZNF324'): 37,
#          ('EWSR1-FLI1', 'ZKSCAN5'): 37,
#          ('ZNF320', 'ZNF528'): 37,
#          ('RREB1', 'SP5'): 37,
#          ('FOXE1', 'PBX3'): 37,
#          ('NEUROD1', 'ZNF93'): 37,
#          ('NEUROG2', 'ZNF93'): 37,
#          ('PATZ1', 'TFDP1'): 37,
#          ('ZNF530', 'ZNF93'): 36,
#          ('PBX3', 'THAP1'): 36,
#          ('ZNF263', 'ZNF528'): 36,
#          ('ZNF528', 'ZNF610'): 36,
#          ('ZNF675', 'ZNF93'): 36,
#          ('PLAG1', 'PRDM9'): 36,
#          ('PATZ1', 'RREB1'): 36,
#          ('KLF4', 'MYF5'): 35,
#          ('KLF4', 'ZNF680'): 35,
#          ('KLF4', 'ZNF768'): 35,
#          ('RARA::RXRA', 'ZNF343'): 35,
#          ('CTCFL', 'ZNF701'): 35,
#          ('EWSR1-FLI1', 'FOXE1'): 35,
#          ('RARA', 'ZNF454'): 35,
#          ('ATF3', 'ZNF460'): 34,
#          ('ATF7', 'ZNF460'): 34,
#          ('CREB3L4', 'ZNF460'): 34,
#          ('CREM', 'ZNF460'): 34,
#          ('E2F2', 'ZNF460'): 34,
#          ('E2F3', 'ZNF460'): 34,
#          ('E2F4', 'ZNF460'): 34,
#          ('E2F7', 'ZNF460'): 34,
#          ('FOS', 'ZNF460'): 34,
#          ('FOS::JUN', 'ZNF460'): 34,
#          ('FOSL2::JUND', 'ZNF460'): 34,
#          ('KLF16', 'ZNF460'): 34,
#          ('KLF5', 'ZNF460'): 34,
#          ('MYOG', 'ZNF460'): 34,
#          ('NR5A1', 'ZNF460'): 34,
#          ('NRF1', 'ZNF460'): 34,
#          ('REST', 'ZNF460'): 34,
#          ('SP3', 'ZNF460'): 34,
#          ('SP8', 'ZNF460'): 34,
#          ('SP9', 'ZNF460'): 34,
#          ('YY1', 'ZNF460'): 34,
#          ('YY2', 'ZNF460'): 34,
#          ('ZBTB6', 'ZKSCAN5'): 34,
#          ('ZBTB6', 'ZNF343'): 34,
#          ('ZFP42', 'ZNF460'): 34,
#          ('ZNF460', 'ZNF549'): 34,
#          ('KLF4', 'ZNF701'): 34,
#          ('CTCFL', 'RARA'): 34,
#          ('BNC2', 'PRDM9'): 34,
#          ('JUN', 'PRDM9'): 34,
#          ('PRDM9', 'RFX1'): 34,
#          ('PRDM9', 'RFX2'): 34,
#          ('PRDM9', 'RFX3'): 34,
#          ('EBF3', 'MYF5'): 34,
#          ('EBF3', 'ZNF680'): 34,
#          ('EBF3', 'ZNF768'): 34,
#          ('RFX1', 'ZNF93'): 34,
#          ('RFX2', 'ZNF93'): 34,
#          ('RFX3', 'ZNF93'): 34,
#          ('SP5', 'ZNF263'): 34,
#          ('SP5', 'ZNF610'): 34,
#          ('FOXE1', 'MYF5'): 34,
#          ('FOXE1', 'ZNF680'): 34,
#          ('FOXE1', 'ZNF768'): 34,
#          ('IRF3', 'RARA::RXRG'): 34,
#          ('MYF5', 'THAP1'): 34,
#          ('RARA::RXRG', 'ZNF135'): 34,
#          ('RARA::RXRG', 'ZNF140'): 34,
#          ('THAP1', 'ZNF680'): 34,
#          ('THAP1', 'ZNF768'): 34,
#          ('RARA', 'TFDP1'): 34,
#          ('IRF3', 'ZNF460'): 34,
#          ('ZNF135', 'ZNF460'): 34,
#          ('ZNF140', 'ZNF460'): 34,
#          ('SP5', 'TFDP1'): 34,
#          ('MAZ', 'THAP1'): 34,
#          ('THAP1', 'ZNF148'): 34,
#          ('IRF3', 'SP5'): 34,
#          ('SP5', 'ZNF135'): 34,
#          ('SP5', 'ZNF140'): 34,
#          ('EBF3', 'ZKSCAN5'): 33,
#          ('PRDM9', 'THRB'): 33,
#          ('RARA::RXRG', 'ZNF263'): 33,
#          ('RARA::RXRG', 'ZNF610'): 33,
#          ('ATF3', 'PRDM9'): 33,
#          ('ATF7', 'PRDM9'): 33,
#          ('CREB3L4', 'PRDM9'): 33,
#          ('CREM', 'PRDM9'): 33,
#          ('E2F2', 'PRDM9'): 33,
#          ('E2F3', 'PRDM9'): 33,
#          ('E2F4', 'PRDM9'): 33,
#          ('E2F7', 'PRDM9'): 33,
#          ('FOS', 'PRDM9'): 33,
#          ('FOS::JUN', 'PRDM9'): 33,
#          ('FOSL2::JUND', 'PRDM9'): 33,
#          ('KLF16', 'PRDM9'): 33,
#          ('KLF5', 'PRDM9'): 33,
#          ('MYOG', 'PRDM9'): 33,
#          ('NR5A1', 'PRDM9'): 33,
#          ('NRF1', 'PRDM9'): 33,
#          ('PRDM9', 'REST'): 33,
#          ('PRDM9', 'SP3'): 33,
#          ('PRDM9', 'SP8'): 33,
#          ('PRDM9', 'SP9'): 33,
#          ('PRDM9', 'YY1'): 33,
#          ('PRDM9', 'YY2'): 33,
#          ('PRDM9', 'ZFP42'): 33,
#          ('PRDM9', 'ZNF549'): 33,
#          ('PRDM9', 'ZNF530'): 33,
#          ('NEUROD1', 'PRDM9'): 33,
#          ('NEUROG2', 'PRDM9'): 33,
#          ('RARA::RXRA', 'RARA::RXRA'): 33,
#          ('RREB1', 'ZNF701'): 33,
#          ('MAZ', 'MAZ'): 33,
#          ('MAZ', 'ZNF148'): 33,
#          ('ZNF148', 'ZNF148'): 33,
#          ('PLAG1', 'ZNF460'): 33,
#          ('RARA::RXRA', 'ZBTB6'): 33,
#          ('CTCFL', 'ZNF528'): 32,
#          ('RARA', 'ZKSCAN5'): 32,
#          ('MAZ', 'ZNF320'): 32,
#          ('ZNF148', 'ZNF320'): 32,
#          ('KLF15', 'PBX3'): 32,
#          ('PBX3', 'ZKSCAN5'): 32,
#          ('ZNF701', 'ZNF701'): 32,
#          ('ZKSCAN5', 'ZNF281'): 32,
#          ('ZNF320', 'ZNF343'): 32,
#          ('RARA', 'ZBTB6'): 32,
#          ('MAZ', 'RREB1'): 32,
#          ('RREB1', 'ZNF148'): 32,
#          ('EWSR1-FLI1', 'THAP1'): 32,
#          ('ERF::NHLH1', 'ZNF460'): 32,
#          ('SOX2', 'ZNF460'): 32,
#          ('TEAD1', 'ZNF460'): 32,
#          ('ZNF257', 'ZNF460'): 32,
#          ('THAP1', 'ZBTB6'): 32,
#          ('MYF5', 'PBX3'): 32,
#          ('PBX3', 'ZNF680'): 32,
#          ('PBX3', 'ZNF768'): 32,
#          ('MAZ', 'ZNF281'): 32,
#          ('ZNF148', 'ZNF281'): 32,
#          ('MYB', 'ZNF93'): 31,
#          ('PRDM9', 'THAP11'): 31,
#          ('KLF15', 'ZBTB6'): 31,
#          ('RARA', 'ZNF320'): 31,
#          ('EWSR1-FLI1', 'KLF4'): 31,
#          ('FOXE1', 'ZBTB6'): 31,
#          ('EWSR1-FLI1', 'PBX3'): 31,
#          ('PBX3', 'ZNF281'): 31,
#          ('RREB1', 'ZNF528'): 31,
#          ('EBF3', 'KLF15'): 31,
#          ('EBF3', 'ZBTB6'): 31,
#          ('KLF15', 'ZNF281'): 31,
#          ('SPI1', 'ZNF460'): 31,
#          ('SPIB', 'ZNF460'): 31,
#          ('ZNF460', 'ZNF574'): 31,
#          ('GATA4', 'RARA::RXRG'): 31,
#          ('FOXE1', 'ZNF343'): 31,
#          ('MYF5', 'RARA::RXRA'): 31,
#          ('RARA::RXRA', 'TFDP1'): 31,
#          ('RARA::RXRA', 'ZNF680'): 31,
#          ('RARA::RXRA', 'ZNF768'): 31,
#          ('IRF3', 'ZNF701'): 31,
#          ('ZNF135', 'ZNF701'): 31,
#          ('ZNF140', 'ZNF701'): 31,
#          ('EBF3', 'KLF4'): 31,
#          ('FOXE1', 'ZKSCAN5'): 30,
#          ('THAP11', 'ZNF93'): 30,
#          ('EHF', 'SP5'): 30,
#          ('ZBTB6', 'ZNF263'): 30,
#          ('ZBTB6', 'ZNF610'): 30,
#          ('KLF15', 'MYF5'): 30,
#          ('KLF15', 'ZNF680'): 30,
#          ('KLF15', 'ZNF768'): 30,
#          ('ATF3', 'ZNF93'): 30,
#          ('ATF7', 'ZNF93'): 30,
#          ('CREB3L4', 'ZNF93'): 30,
#          ('CREM', 'ZNF93'): 30,
#          ('E2F2', 'ZNF93'): 30,
#          ('E2F3', 'ZNF93'): 30,
#          ('E2F4', 'ZNF93'): 30,
#          ('E2F7', 'ZNF93'): 30,
#          ('FOS', 'ZNF93'): 30,
#          ('FOS::JUN', 'ZNF93'): 30,
#          ('FOSL2::JUND', 'ZNF93'): 30,
#          ('KLF16', 'ZNF93'): 30,
#          ('KLF5', 'ZNF93'): 30,
#          ('MYOG', 'ZNF93'): 30,
#          ('NR5A1', 'ZNF93'): 30,
#          ('NRF1', 'ZNF93'): 30,
#          ('REST', 'ZNF93'): 30,
#          ('SP3', 'ZNF93'): 30,
#          ('SP8', 'ZNF93'): 30,
#          ('SP9', 'ZNF93'): 30,
#          ('YY1', 'ZNF93'): 30,
#          ('YY2', 'ZNF93'): 30,
#          ('ZFP42', 'ZNF93'): 30,
#          ('ZNF549', 'ZNF93'): 30,
#          ('BNC2', 'RARA::RXRG'): 30,
#          ('JUN', 'RARA::RXRG'): 30,
#          ('NR2C2', 'ZNF460'): 30,
#          ('ZNF324', 'ZNF93'): 30,
#          ('CTCFL', 'PBX3'): 30,
#          ('GATA4', 'PRDM9'): 30,
#          ('CTCF', 'PRDM9'): 30,
#          ('ELF1', 'PRDM9'): 30,
#          ('ERF::FOXI1', 'PRDM9'): 30,
#          ('NEUROD1', 'ZNF460'): 30,
#          ('NEUROG2', 'ZNF460'): 30,
#          ('CTCF', 'ZNF460'): 30,
#          ('ELF1', 'ZNF460'): 30,
#          ('ERF::FOXI1', 'ZNF460'): 30,
#          ('CTCFL', 'RARA::RXRA'): 30,
#          ('KLF4', 'ZNF343'): 30,
#          ('IRF3', 'RARA'): 30,
#          ('RARA', 'ZNF135'): 30,
#          ('RARA', 'ZNF140'): 30,
#          ('IRF3', 'ZNF454'): 30,
#          ('ZNF135', 'ZNF454'): 30,
#          ('ZNF140', 'ZNF454'): 30,
#          ('ZNF460', 'ZNF530'): 30,
#          ('EBF3', 'ZNF343'): 30,
#          ('SPI1', 'ZNF93'): 29,
#          ('SPIB', 'ZNF93'): 29,
#          ('ZNF574', 'ZNF93'): 29,
#          ('TFDP1', 'ZNF454'): 29,
#          ('RARA::RXRA', 'ZKSCAN5'): 29,
#          ('STAT3', 'ZNF93'): 29,
#          ('CTCFL', 'PATZ1'): 29,
#          ('PLAG1', 'ZNF93'): 29,
#          ('ZNF528', 'ZNF528'): 29,
#          ('GATA4', 'ZNF93'): 29,
#          ('GATA4', 'PATZ1'): 29,
#          ('FOXE1', 'ZNF281'): 29,
#          ('IRF3', 'ZNF528'): 29,
#          ('ZNF135', 'ZNF528'): 29,
#          ('ZNF140', 'ZNF528'): 29,
#          ('EBF3', 'ZNF281'): 29,
#          ('ZNF343', 'ZNF343'): 29,
#          ('THAP1', 'ZKSCAN5'): 28,
#          ('MYB', 'PRDM9'): 28,
#          ('PBX3', 'ZBTB6'): 28,
#          ('NFE2L2', 'ZNF93'): 28,
#          ('NFE2L2', 'RARA::RXRG'): 28,
#          ('SP5', 'ZNF675'): 28,
#          ('PBX3', 'ZNF701'): 28,
#          ('CTCF', 'ZNF93'): 28,
#          ('ELF1', 'ZNF93'): 28,
#          ('ERF::FOXI1', 'ZNF93'): 28,
#          ('RARA', 'RARA'): 28,
#          ('NR2C2', 'PRDM9'): 28,
#          ('FOXE1', 'KLF15'): 28,
#          ('FOXE1', 'KLF4'): 28,
#          ('RARA::RXRA', 'RREB1'): 28,
#          ('KLF15', 'ZKSCAN5'): 28,
#          ('ZNF384', 'ZNF93'): 28,
#          ('E2F6', 'ZNF460'): 28,
#          ('MTF1', 'ZNF460'): 28,
#          ('NR2C2', 'ZNF93'): 28,
#          ('KLF4', 'ZNF281'): 28,
#          ('EHF', 'ZNF528'): 28,
#          ('PATZ1', 'THRB'): 27,
#          ('PATZ1', 'THAP11'): 27,
#          ('MYF5', 'ZNF343'): 27,
#          ('RARA::RXRA', 'ZNF320'): 27,
#          ('ZNF343', 'ZNF680'): 27,
#          ('ZNF343', 'ZNF768'): 27,
#          ('PBX3', 'ZNF343'): 27,
#          ('RARA', 'RREB1'): 27,
#          ('EHF', 'RARA'): 27,
#          ('CTCFL', 'SP5'): 27,
#          ('NFE2L2', 'ZNF460'): 27,
#          ('ERF::NHLH1', 'SP5'): 27,
#          ('ERF::NHLH1', 'ZNF93'): 27,
#          ('SOX2', 'SP5'): 27,
#          ('SOX2', 'ZNF93'): 27,
#          ('SP5', 'TEAD1'): 27,
#          ('SP5', 'ZNF257'): 27,
#          ('TEAD1', 'ZNF93'): 27,
#          ('ZNF257', 'ZNF93'): 27,
#          ('EHF', 'ZNF701'): 27,
#          ('MAZ', 'ZNF263'): 27,
#          ('MAZ', 'ZNF610'): 27,
#          ('ZNF148', 'ZNF263'): 27,
#          ('ZNF148', 'ZNF610'): 27,
#          ('IRF3', 'RARA::RXRA'): 27,
#          ('RARA::RXRA', 'ZNF135'): 27,
#          ('RARA::RXRA', 'ZNF140'): 27,
#          ('NEUROD1', 'PATZ1'): 27,
#          ('NEUROG2', 'PATZ1'): 27,
#          ('IRF3', 'PBX3'): 27,
#          ('PBX3', 'ZNF135'): 27,
#          ('PBX3', 'ZNF140'): 27,
#          ('ZKSCAN5', 'ZNF343'): 27,
#          ('KLF15', 'KLF4'): 27,
#          ('STAT3', 'ZNF460'): 26,
#          ('SP5', 'THRB'): 26,
#          ('EHF', 'ZNF454'): 26,
#          ('PATZ1', 'ZNF675'): 26,
#          ('PRDM1', 'ZNF460'): 26,
#          ('KLF4', 'PBX3'): 26,
#          ('ZNF263', 'ZNF701'): 26,
#          ('ZNF610', 'ZNF701'): 26,
#          ('CTCFL', 'ZNF454'): 26,
#          ('BNC2', 'ZNF93'): 26,
#          ('JUN', 'ZNF93'): 26,
#          ('ERF::NHLH1', 'PATZ1'): 26,
#          ('PATZ1', 'SOX2'): 26,
#          ('PATZ1', 'TEAD1'): 26,
#          ('PATZ1', 'ZNF257'): 26,
#          ('BNC2', 'PATZ1'): 26,
#          ('JUN', 'PATZ1'): 26,
#          ('KLF9', 'ZNF93'): 26,
#          ('MYF5', 'TFDP1'): 26,
#          ('TFDP1', 'ZNF680'): 26,
#          ('TFDP1', 'ZNF768'): 26,
#          ('EBF3', 'ZNF320'): 26,
#          ('E2F6', 'ZNF93'): 25,
#          ('MTF1', 'ZNF93'): 25,
#          ('EHF', 'MAZ'): 25,
#          ('EHF', 'ZNF148'): 25,
#          ('ZBTB6', 'ZNF320'): 25,
#          ('RREB1', 'ZNF281'): 25,
#          ('MYF5', 'RARA'): 25,
#          ('RARA', 'ZNF680'): 25,
#          ('RARA', 'ZNF768'): 25,
#          ('ZNF263', 'ZNF343'): 25,
#          ('ZNF343', 'ZNF610'): 25,
#          ('PRDM1', 'ZNF93'): 25,
#          ('MYF5', 'ZNF454'): 25,
#          ('ZNF454', 'ZNF680'): 25,
#          ('ZNF454', 'ZNF768'): 25,
#          ('EHF', 'EWSR1-FLI1'): 25,
#          ('KLF4', 'THAP1'): 25,
#          ('KLF9', 'PRDM9'): 25,
#          ('EWSR1-FLI1', 'ZNF263'): 25,
#          ('EWSR1-FLI1', 'ZNF610'): 25,
#          ('EWSR1-FLI1', 'EWSR1-FLI1'): 25,
#          ('KLF4', 'ZKSCAN5'): 25,
#          ('PBX3', 'RREB1'): 25,
#          ('RREB1', 'THAP1'): 25,
#          ('EHF', 'ZKSCAN5'): 24,
#          ('EWSR1-FLI1', 'TFDP1'): 24,
#          ('ZNF281', 'ZNF320'): 24,
#          ('CTCFL', 'MAZ'): 24,
#          ('CTCFL', 'ZNF148'): 24,
#          ('EWSR1-FLI1', 'THRB'): 24,
#          ('RARA::RXRG', 'ZNF530'): 24,
#          ('GATA4', 'RARA'): 24,
#          ('KLF9', 'RARA::RXRG'): 24,
#          ('NEUROD1', 'SP5'): 24,
#          ('NEUROG2', 'SP5'): 24,
#          ('ZNF460', 'ZNF675'): 24,
#          ('KLF15', 'THAP1'): 24,
#          ('THAP1', 'ZNF281'): 24,
#          ('EHF', 'THAP1'): 24,
#          ('ERF::NHLH1', 'RARA::RXRG'): 24,
#          ('RARA::RXRG', 'SOX2'): 24,
#          ('RARA::RXRG', 'TEAD1'): 24,
#          ('RARA::RXRG', 'ZNF257'): 24,
#          ('THRB', 'ZNF460'): 23,
#          ('MYF5', 'ZKSCAN5'): 23,
#          ('MYF5', 'ZNF320'): 23,
#          ('RARA', 'ZNF263'): 23,
#          ('RARA', 'ZNF610'): 23,
#          ('RARA::RXRA', 'ZNF263'): 23,
#          ('RARA::RXRA', 'ZNF610'): 23,
#          ('ZKSCAN5', 'ZNF680'): 23,
#          ('ZKSCAN5', 'ZNF768'): 23,
#          ('ZNF320', 'ZNF680'): 23,
#          ('ZNF320', 'ZNF768'): 23,
#          ('ZNF320', 'ZNF701'): 23,
#          ('ERF::NHLH1', 'MAZ'): 23,
#          ('ERF::NHLH1', 'ZNF148'): 23,
#          ('MAZ', 'SOX2'): 23,
#          ('MAZ', 'TEAD1'): 23,
#          ('MAZ', 'ZNF257'): 23,
#          ('SOX2', 'ZNF148'): 23,
#          ('TEAD1', 'ZNF148'): 23,
#          ('ZNF148', 'ZNF257'): 23,
#          ('EHF', 'ZBTB6'): 23,
#          ('CTCFL', 'MYF5'): 23,
#          ('CTCFL', 'ZNF680'): 23,
#          ('CTCFL', 'ZNF768'): 23,
#          ('PRDM9', 'SPI1'): 23,
#          ('PRDM9', 'SPIB'): 23,
#          ('PRDM9', 'ZNF574'): 23,
#          ('NR2C2', 'PATZ1'): 23,
#          ('GATA4', 'ZNF460'): 23,
#          ('IRF3', 'MAZ'): 23,
#          ('IRF3', 'ZNF148'): 23,
#          ('MAZ', 'ZNF135'): 23,
#          ('MAZ', 'ZNF140'): 23,
#          ('ZNF135', 'ZNF148'): 23,
#          ('ZNF140', 'ZNF148'): 23,
#          ('NFE2L2', 'PATZ1'): 23,
#          ('ATF3', 'PATZ1'): 23,
#          ('ATF7', 'PATZ1'): 23,
#          ('CREB3L4', 'PATZ1'): 23,
#          ('CREM', 'PATZ1'): 23,
#          ('E2F2', 'PATZ1'): 23,
#          ('E2F3', 'PATZ1'): 23,
#          ('E2F4', 'PATZ1'): 23,
#          ('E2F7', 'PATZ1'): 23,
#          ('FOS', 'PATZ1'): 23,
#          ('FOS::JUN', 'PATZ1'): 23,
#          ('FOSL2::JUND', 'PATZ1'): 23,
#          ('KLF16', 'PATZ1'): 23,
#          ('KLF5', 'PATZ1'): 23,
#          ('MYOG', 'PATZ1'): 23,
#          ('NR5A1', 'PATZ1'): 23,
#          ('NRF1', 'PATZ1'): 23,
#          ('PATZ1', 'REST'): 23,
#          ('PATZ1', 'SP3'): 23,
#          ('PATZ1', 'SP8'): 23,
#          ('PATZ1', 'SP9'): 23,
#          ('PATZ1', 'YY1'): 23,
#          ('PATZ1', 'YY2'): 23,
#          ('PATZ1', 'ZFP42'): 23,
#          ('PATZ1', 'ZNF549'): 23,
#          ('TFDP1', 'ZNF528'): 23,
#          ('TFDP1', 'ZBTB6'): 23,
#          ('MYF5', 'ZBTB6'): 23,
#          ('ZBTB6', 'ZNF680'): 23,
#          ('ZBTB6', 'ZNF768'): 23,
#          ('ZNF263', 'ZNF454'): 23,
#          ('ZNF320', 'ZNF454'): 23,
#          ('ZNF454', 'ZNF610'): 23,
#          ('TFDP1', 'ZNF701'): 22,
#          ('ZNF324', 'ZNF460'): 22,
#          ('THRB', 'ZNF701'): 22,
#          ('MAZ', 'ZNF675'): 22,
#          ('ZNF148', 'ZNF675'): 22,
#          ('RREB1', 'ZNF454'): 22,
#          ('CTCF', 'RARA::RXRG'): 22,
#          ('ELF1', 'RARA::RXRG'): 22,
#          ('ERF::FOXI1', 'RARA::RXRG'): 22,
#          ('PATZ1', 'ZNF324'): 22,
#          ('EBF3', 'FOXE1'): 22,
#          ('EBF3', 'RREB1'): 22,
#          ('EWSR1-FLI1', 'ZNF320'): 22,
#          ('EWSR1-FLI1', 'IRF3'): 22,
#          ('EWSR1-FLI1', 'ZNF135'): 22,
#          ('EWSR1-FLI1', 'ZNF140'): 22,
#          ('PATZ1', 'PRDM1'): 22,
#          ('EBF3', 'EHF'): 22,
#          ('KLF15', 'ZNF263'): 22,
#          ('KLF15', 'ZNF610'): 22,
#          ('ZNF263', 'ZNF281'): 22,
#          ('ZNF281', 'ZNF610'): 22,
#          ('IRF3', 'MYF5'): 22,
#          ('IRF3', 'ZNF680'): 22,
#          ('IRF3', 'ZNF768'): 22,
#          ('MYF5', 'ZNF135'): 22,
#          ('MYF5', 'ZNF140'): 22,
#          ('ZNF135', 'ZNF680'): 22,
#          ('ZNF135', 'ZNF768'): 22,
#          ('ZNF140', 'ZNF680'): 22,
#          ('ZNF140', 'ZNF768'): 22,
#          ('GATA4', 'ZNF454'): 22,
#          ('THAP1', 'ZNF343'): 22,
#          ('ZNF454', 'ZNF454'): 22,
#          ('MAZ', 'TFDP1'): 22,
#          ('TFDP1', 'ZNF148'): 22,
#          ('CTCFL', 'ZKSCAN5'): 22,
#          ('PLAG1', 'RARA::RXRG'): 22,
#          ('ATF3', 'SP5'): 22,
#          ('ATF7', 'SP5'): 22,
#          ('CREB3L4', 'SP5'): 22,
#          ('CREM', 'SP5'): 22,
#          ('E2F2', 'SP5'): 22,
#          ('E2F3', 'SP5'): 22,
#          ('E2F4', 'SP5'): 22,
#          ('E2F7', 'SP5'): 22,
#          ('FOS', 'SP5'): 22,
#          ('FOS::JUN', 'SP5'): 22,
#          ('FOSL2::JUND', 'SP5'): 22,
#          ('KLF16', 'SP5'): 22,
#          ('KLF5', 'SP5'): 22,
#          ('MYOG', 'SP5'): 22,
#          ('NR5A1', 'SP5'): 22,
#          ('NRF1', 'SP5'): 22,
#          ('REST', 'SP5'): 22,
#          ('SP3', 'SP5'): 22,
#          ('SP5', 'SP8'): 22,
#          ('SP5', 'SP9'): 22,
#          ('SP5', 'YY1'): 22,
#          ('SP5', 'YY2'): 22,
#          ('SP5', 'ZFP42'): 22,
#          ('SP5', 'ZNF549'): 22,
#          ('NFE2L2', 'ZKSCAN5'): 22,
#          ('EHF', 'RARA::RXRA'): 22,
#          ('NEUROD1', 'RARA::RXRG'): 22,
#          ('NEUROG2', 'RARA::RXRG'): 22,
#          ('E2F6', 'PRDM9'): 21,
#          ('MTF1', 'PRDM9'): 21,
#          ('ZNF343', 'ZNF675'): 21,
#          ('ZKSCAN5', 'ZNF320'): 21,
#          ('KLF15', 'RREB1'): 21,
#          ('CTCFL', 'THAP1'): 21,
#          ('NFE2L2', 'SP5'): 21,
#          ('KLF4', 'ZNF263'): 21,
#          ('KLF4', 'ZNF610'): 21,
#          ('FOXE1', 'ZNF320'): 21,
#          ('THAP11', 'ZNF460'): 21,
#          ('MAZ', 'NEUROD1'): 21,
#          ('MAZ', 'NEUROG2'): 21,
#          ('NEUROD1', 'ZNF148'): 21,
#          ('NEUROG2', 'ZNF148'): 21,
#          ('EHF', 'FOXE1'): 21,
#          ('PRDM9', 'ZNF384'): 21,
#          ('ATF3', 'ZNF528'): 21,
#          ('ATF7', 'ZNF528'): 21,
#          ('CREB3L4', 'ZNF528'): 21,
#          ('CREM', 'ZNF528'): 21,
#          ('E2F2', 'ZNF528'): 21,
#          ('E2F3', 'ZNF528'): 21,
#          ('E2F4', 'ZNF528'): 21,
#          ('E2F7', 'ZNF528'): 21,
#          ('FOS', 'ZNF528'): 21,
#          ('FOS::JUN', 'ZNF528'): 21,
#          ('FOSL2::JUND', 'ZNF528'): 21,
#          ('KLF16', 'ZNF528'): 21,
#          ('KLF5', 'ZNF528'): 21,
#          ('MYOG', 'ZNF528'): 21,
#          ('NR5A1', 'ZNF528'): 21,
#          ('NRF1', 'ZNF528'): 21,
#          ('REST', 'ZNF528'): 21,
#          ('SP3', 'ZNF528'): 21,
#          ('SP8', 'ZNF528'): 21,
#          ('SP9', 'ZNF528'): 21,
#          ('YY1', 'ZNF528'): 21,
#          ('YY2', 'ZNF528'): 21,
#          ('ZFP42', 'ZNF528'): 21,
#          ('ZNF528', 'ZNF549'): 21,
#          ('MAZ', 'THRB'): 20,
#          ('THRB', 'ZNF148'): 20,
#          ('PATZ1', 'RFX1'): 20,
#          ('PATZ1', 'RFX2'): 20,
#          ('PATZ1', 'RFX3'): 20,
#          ('SP5', 'THAP11'): 20,
#          ('RREB1', 'ZKSCAN5'): 20,
#          ('NFE2L2', 'RARA'): 20,
#          ('NFE2L2', 'RARA::RXRA'): 20,
#          ('PRDM1', 'RARA::RXRG'): 20,
#          ('KLF15', 'ZNF320'): 20,
#          ('PBX3', 'ZNF263'): 20,
#          ('PBX3', 'ZNF610'): 20,
#          ('ZNF675', 'ZNF701'): 20,
#          ('RARA::RXRG', 'SPI1'): 20,
#          ('RARA::RXRG', 'SPIB'): 20,
#          ('RARA::RXRG', 'ZNF574'): 20,
#          ('SP5', 'ZNF324'): 20,
#          ('RFX1', 'ZNF460'): 20,
#          ('RFX2', 'ZNF460'): 20,
#          ('RFX3', 'ZNF460'): 20,
#          ('RFX1', 'SP5'): 20,
#          ('RFX2', 'SP5'): 20,
#          ('RFX3', 'SP5'): 20,
#          ('THRB', 'ZNF454'): 20,
#          ('EHF', 'PBX3'): 20,
#          ('CTCFL', 'TFDP1'): 20,
#          ('GATA4', 'RARA::RXRA'): 20,
#          ('RARA::RXRG', 'ZNF675'): 20,
#          ('RREB1', 'TFDP1'): 20,
#          ('THAP1', 'ZNF320'): 20,
#          ('EBF3', 'ZNF263'): 20,
#          ('EBF3', 'ZNF610'): 20,
#          ('ZNF281', 'ZNF281'): 20,
#          ('ERF::NHLH1', 'ZNF701'): 20,
#          ('SOX2', 'ZNF701'): 20,
#          ('TEAD1', 'ZNF701'): 20,
#          ('ZNF257', 'ZNF701'): 20,
#          ('FOXE1', 'RREB1'): 20,
#          ('PBX3', 'TFDP1'): 19,
#          ('PATZ1', 'SPI1'): 19,
#          ('PATZ1', 'SPIB'): 19,
#          ('PATZ1', 'ZNF574'): 19,
#          ('MAZ', 'THAP11'): 19,
#          ('THAP11', 'ZNF148'): 19,
#          ('ATF3', 'RARA::RXRG'): 19,
#          ('ATF7', 'RARA::RXRG'): 19,
#          ('CREB3L4', 'RARA::RXRG'): 19,
#          ('CREM', 'RARA::RXRG'): 19,
#          ('E2F2', 'RARA::RXRG'): 19,
#          ('E2F3', 'RARA::RXRG'): 19,
#          ('E2F4', 'RARA::RXRG'): 19,
#          ('E2F7', 'RARA::RXRG'): 19,
#          ('FOS', 'RARA::RXRG'): 19,
#          ('FOS::JUN', 'RARA::RXRG'): 19,
#          ('FOSL2::JUND', 'RARA::RXRG'): 19,
#          ('KLF16', 'RARA::RXRG'): 19,
#          ('KLF5', 'RARA::RXRG'): 19,
#          ('MYOG', 'RARA::RXRG'): 19,
#          ('NR5A1', 'RARA::RXRG'): 19,
#          ('NRF1', 'RARA::RXRG'): 19,
#          ('RARA::RXRG', 'REST'): 19,
#          ('RARA::RXRG', 'SP3'): 19,
#          ('RARA::RXRG', 'SP8'): 19,
#          ('RARA::RXRG', 'SP9'): 19,
#          ('RARA::RXRG', 'YY1'): 19,
#          ('RARA::RXRG', 'YY2'): 19,
#          ('RARA::RXRG', 'ZFP42'): 19,
#          ('RARA::RXRG', 'ZNF549'): 19,
#          ('CTCFL', 'ZNF281'): 19,
#          ('MYB', 'ZNF460'): 19,
#          ('MYB', 'ZNF528'): 19,
#          ('RARA::RXRG', 'STAT3'): 19,
#          ('CTCF', 'ZNF701'): 19,
#          ('ELF1', 'ZNF701'): 19,
#          ('ERF::FOXI1', 'ZNF701'): 19,
#          ('PATZ1', 'ZNF384'): 19,
#          ('CTCF', 'PATZ1'): 19,
#          ('EHF', 'ZNF281'): 19,
#          ('ELF1', 'PATZ1'): 19,
#          ('ERF::FOXI1', 'PATZ1'): 19,
#          ('CTCFL', 'EWSR1-FLI1'): 19,
#          ('KLF9', 'RARA'): 19,
#          ('EHF', 'KLF4'): 19,
#          ('GATA4', 'ZBTB6'): 19,
#          ('IRF3', 'ZBTB6'): 19,
#          ('ZBTB6', 'ZNF135'): 19,
#          ('ZBTB6', 'ZNF140'): 19,
#          ('E2F6', 'RARA::RXRG'): 19,
#          ('MTF1', 'RARA::RXRG'): 19,
#          ('CTCFL', 'ZNF343'): 19,
#          ('RREB1', 'ZNF343'): 19,
#          ('MYB', 'ZNF454'): 19,
#          ('EBF3', 'THAP1'): 19,
#          ('BNC2', 'EBF3'): 19,
#          ('EBF3', 'JUN'): 19,
#          ('MAZ', 'NFE2L2'): 19,
#          ('NFE2L2', 'ZNF148'): 19,
#          ('KLF9', 'PATZ1'): 19,
#          ('NFE2L2', 'ZNF701'): 19,
#          ('BNC2', 'FOXE1'): 19,
#          ('FOXE1', 'JUN'): 19,
#          ('MYF5', 'RREB1'): 19,
#          ('RREB1', 'ZNF680'): 19,
#          ('RREB1', 'ZNF768'): 19,
#          ('BNC2', 'THAP1'): 19,
#          ('JUN', 'THAP1'): 19,
#          ('THAP11', 'ZNF701'): 18,
#          ('EWSR1-FLI1', 'THAP11'): 18,
#          ('KLF9', 'ZNF460'): 18,
#          ('RARA::RXRA', 'RFX1'): 18,
#          ('RARA::RXRA', 'RFX2'): 18,
#          ('RARA::RXRA', 'RFX3'): 18,
#          ('BNC2', 'SP5'): 18,
#          ('JUN', 'SP5'): 18,
#          ('GATA4', 'MYF5'): 18,
#          ('GATA4', 'ZNF680'): 18,
#          ('GATA4', 'ZNF768'): 18,
#          ('BNC2', 'ZNF528'): 18,
#          ('JUN', 'ZNF528'): 18,
#          ('GATA4', 'ZNF528'): 18,
#          ('EHF', 'KLF15'): 18,
#          ('RARA::RXRG', 'THAP11'): 18,
#          ('ERF::NHLH1', 'RARA::RXRA'): 18,
#          ('KLF9', 'SP5'): 18,
#          ('RARA::RXRA', 'SOX2'): 18,
#          ('RARA::RXRA', 'TEAD1'): 18,
#          ('RARA::RXRA', 'ZNF257'): 18,
#          ('E2F6', 'PATZ1'): 18,
#          ('MTF1', 'PATZ1'): 18,
#          ('EWSR1-FLI1', 'RREB1'): 18,
#          ('BNC2', 'ZNF454'): 18,
#          ('JUN', 'ZNF454'): 18,
#          ('ZKSCAN5', 'ZKSCAN5'): 18,
#          ('KLF15', 'KLF15'): 18,
#          ('ZKSCAN5', 'ZNF263'): 18,
#          ('ZKSCAN5', 'ZNF610'): 18,
#          ('PBX3', 'PBX3'): 18,
#          ('TFDP1', 'ZKSCAN5'): 18,
#          ('KLF15', 'NFE2L2'): 18,
#          ('PATZ1', 'PLAG1'): 18,
#          ('KLF15', 'THRB'): 17,
#          ('KLF4', 'THAP11'): 17,
#          ('MYF5', 'ZNF263'): 17,
#          ('MYF5', 'ZNF610'): 17,
#          ('ZNF263', 'ZNF680'): 17,
#          ('ZNF263', 'ZNF768'): 17,
#          ('ZNF610', 'ZNF680'): 17,
#          ('ZNF610', 'ZNF768'): 17,
#          ('CTCFL', 'ZNF320'): 17,
#          ('EWSR1-FLI1', 'ZNF675'): 17,
#          ('EBF3', 'ZNF530'): 17,
#          ...})

# %%
###############################################################################
# Save json file to output
###############################################################################
print('# Save json file to output')

# Keys are from observed
# Aggregate simulations into one list only for observed motif pairs   
mp_sim_aggs = defaultdict(list)
for sim_idx in range(sims):
    for mp in uniq_motif_pairs:
        mp_sim_aggs[str(mp)].append(sim_results[sim_idx][mp])

# # Save json
# json_d = json.dumps(mp_sim_aggs)
# with open(savepath, 'w') as fw:
#     fw.write(json_d)
# Out:
# # Counting Observed
# # Construct Anchor Slots
# # Conduct Simulations
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /mnt/BioAdHoc/Groups/vd-ay/jreyna/software/Herman-Cluster-v3/mambaforge-pypy3/envs/lc-pipelines/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('anchor_name1', 'anchor_name2')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 171
#     168 while sim_idx < sims:
#     170     sims_motif_pair_counter = Counter()
# --> 171     for anchor_name1, anchor_name2 in filter_df['anchor_name1', 'anchor_name2'].values:
#     172
#     173         # Simulate anchors based on chromsome and distance
#     174         sim_anchors1 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True)
#     175         sim_anchors2 = np.random.choice(anchor_shuffle_dict[anchor_name], size=1, replace=True)
#
# File /mnt/BioAdHoc/Groups/vd-ay/jreyna/software/Herman-Cluster-v3/mambaforge-pypy3/envs/lc-pipelines/lib/python3.12/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /mnt/BioAdHoc/Groups/vd-ay/jreyna/software/Herman-Cluster-v3/mambaforge-pypy3/envs/lc-pipelines/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: ('anchor_name1', 'anchor_name2')
